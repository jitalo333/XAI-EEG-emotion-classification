# %% [markdown]
# # Method 1

# %% [markdown]
# Explanation of Method 1 usage with code and implementation examples (follow this structure for all methods).

# %%
from XAI import XAI_module

model_path = ""
savepath = ""
verbose = True
explainable = XAI_module(model_path, savepath, verbose)

args = {}
explainable.method1(args)
